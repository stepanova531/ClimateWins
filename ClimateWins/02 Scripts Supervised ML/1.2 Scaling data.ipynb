# %% [markdown]
# # ClimateWins Project

# %% [markdown]
# ## Content
# ### 1. Importing data and libraries
# ### 2. Scaling
# ### 2.1 Subsetting data
# ### 2.2 Check for (and handle) missing values
# ### 2.3 Scaling
# ### 3. Exporting data

# %%
## 1. Importing data and libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
# Create Path
path="C:/Users/Oksana Stepanova/OneDrive/Документи/ClimateWins/02 Data/Original Data/"

# %%
# Import data
df=pd.read_csv(os.path.join(path, 'Dataset-weather-prediction-dataset-processed.csv'))

# %%
df.shape
# Out:
# (22950, 170)

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
# Reset index
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# 0      0  19600101      1                  7               2.1
# 1      1  19600102      1                  6               2.1
# 2      2  19600103      1                  8               2.1
# 3      3  19600104      1                  3               2.1
# 4      4  19600105      1                  6               2.1
#
#    BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# 0            0.85           1.018                    0.32
# 1            0.84           1.018                    0.36
# 2            0.90           1.018                    0.18
# 3            0.92           1.018                    0.58
# 4            0.95           1.018                    0.65
#
#    BASEL_precipitation  BASEL_snow_depth  ...  VALENTIA_cloud_cover  \
# 0                 0.09                 0  ...                     5
# 1                 1.05                 0  ...                     7
# ...

# %%
# Rename index column
df.rename(columns={'index': 'id'}, inplace=True)

# %%
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
df.shape
# Out:
# (22950, 171)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %%
pd.set_option('display.max_columns', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %%
pd.set_option('display.max_info_columns', 200)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Data columns (total 171 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    id                           22950 non-null  int64
#  1    DATE                         22950 non-null  int64
#  2    MONTH                        22950 non-null  int64
#  3    BASEL_cloud_cover            22950 non-null  int64
#  4    BASEL_wind_speed             22950 non-null  float64
#  5    BASEL_humidity               22950 non-null  float64
#  6    BASEL_pressure               22950 non-null  float64
#  7    BASEL_global_radiation       22950 non-null  float64
#  8    BASEL_precipitation          22950 non-null  float64
#  9    BASEL_snow_depth             22950 non-null  int64
#  10   BASEL_sunshine               22950 non-null  float64
#  11   BASEL_temp_mean              22950 non-null  float64
# ...

# %% [markdown]
# ## 2. Scaling

# %% [markdown]
# ### 2.1 Subsetting data

# %%
# drop columns id, DATE and MONTH
df2=df.drop(columns=['id', 'DATE', 'MONTH'])

# %%
df2.head()
# Out:
#    BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0                  7               2.1            0.85           1.018
# 1                  6               2.1            0.84           1.018
# 2                  8               2.1            0.90           1.018
# 3                  3               2.1            0.92           1.018
# 4                  6               2.1            0.95           1.018
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_snow_depth  \
# 0                    0.32                 0.09                 0
# 1                    0.36                 1.05                 0
# 2                    0.18                 0.30                 0
# 3                    0.58                 0.00                 0
# 4                    0.65                 0.14                 0
#
#    BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  BASEL_temp_max  \
# 0             0.7              6.5             0.8            10.9
# ...

# %%
df2.shape
# Out:
# (22950, 168)

# %% [markdown]
# ### 2.2 Check for (and handle) missing values

# %%
df2.isnull().sum()
# Out:
# BASEL_cloud_cover         0
# BASEL_wind_speed          0
# BASEL_humidity            0
# BASEL_pressure            0
# BASEL_global_radiation    0
#                          ..
# VALENTIA_snow_depth       0
# VALENTIA_sunshine         0
# VALENTIA_temp_mean        0
# VALENTIA_temp_min         0
# VALENTIA_temp_max         0
# Length: 168, dtype: int64

# %%
pd.set_option('display.max_columns', None)
print(df2.isnull().sum())
# Out:
# BASEL_cloud_cover         0
# BASEL_wind_speed          0
# BASEL_humidity            0
# BASEL_pressure            0
# BASEL_global_radiation    0
#                          ..
# VALENTIA_snow_depth       0
# VALENTIA_sunshine         0
# VALENTIA_temp_mean        0
# VALENTIA_temp_min         0
# VALENTIA_temp_max         0
# Length: 168, dtype: int64

# %%
pd.set_option('display.max_columns', 200)
print(df2.isnull().sum())
# Out:
# BASEL_cloud_cover         0
# BASEL_wind_speed          0
# BASEL_humidity            0
# BASEL_pressure            0
# BASEL_global_radiation    0
#                          ..
# VALENTIA_snow_depth       0
# VALENTIA_sunshine         0
# VALENTIA_temp_mean        0
# VALENTIA_temp_min         0
# VALENTIA_temp_max         0
# Length: 168, dtype: int64

# %%
missing_values = df2.isnull().sum()
print(missing_values)
# Out:
# BASEL_cloud_cover         0
# BASEL_wind_speed          0
# BASEL_humidity            0
# BASEL_pressure            0
# BASEL_global_radiation    0
#                          ..
# VALENTIA_snow_depth       0
# VALENTIA_sunshine         0
# VALENTIA_temp_mean        0
# VALENTIA_temp_min         0
# VALENTIA_temp_max         0
# Length: 168, dtype: int64

# %%
missing_values_df = missing_values.to_frame(name='missing_count')
print(missing_values_df)
# Out:
#                         missing_count
# BASEL_cloud_cover                   0
# BASEL_wind_speed                    0
# BASEL_humidity                      0
# BASEL_pressure                      0
# BASEL_global_radiation              0
# ...                               ...
# VALENTIA_snow_depth                 0
# VALENTIA_sunshine                   0
# VALENTIA_temp_mean                  0
# VALENTIA_temp_min                   0
# VALENTIA_temp_max                   0
#
# [168 rows x 1 columns]

# %% [markdown]
# ### 2.3 Scaling

# %%
#create scaler object using StandardScaler from sklearn.preprocessing
#StandardScaler assumes data is normally distributed and scales with a distribution
#around 0 and standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
df_scaled=pd.DataFrame(scaler.fit_transform(df2), columns=columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df_scaled=pd.DataFrame(scaler.fit_transform(df2), columns=columns)
#
# NameError: name 'columns' is not defined

# %%
df_scaled2=pd.DataFrame(scaler.fit_transform(df2))

# %%
df_scaled2.head()
# Out:
#         0        1         2         3         4         5         6    \
# 0  0.660514 -0.02793  0.826097 -0.001949 -1.101066 -0.265148 -0.179228
# 1  0.244897 -0.02793  0.735760 -0.001949 -1.058108  1.658760 -0.179228
# 2  1.076130 -0.02793  1.277781 -0.001949 -1.251420  0.155707 -0.179228
# 3 -1.001953 -0.02793  1.458455 -0.001949 -0.821838 -0.445514 -0.179228
# 4  0.244897 -0.02793  1.729466 -0.001949 -0.746661 -0.164944 -0.179228
#
#         7         8         9         10        11        12        13   \
# 0 -0.902918 -0.528623 -0.845652 -0.478356 -1.206433  0.905270  0.321771
# 1 -0.810126 -0.582946 -0.462450 -0.569988  0.652846  1.119118  0.016838
# 2 -1.065304 -0.257010 -0.186545 -0.592896  0.652846  0.620141  0.109644
# 3 -0.114186 -0.555784 -0.385810 -0.512718  1.396557  1.760659  1.289601
# 4  0.187388 -1.003946 -1.075573 -1.039603  1.396557  2.188353  1.528244
#
#         14        15        16        17        18        19       20   \
# ...

# %%
df_scaled3=pd.DataFrame(scaler.fit_transform(df2), columns=df2.columns)

# %%
df_scaled3.head()
# Out:
#    BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0           0.660514          -0.02793        0.826097       -0.001949
# 1           0.244897          -0.02793        0.735760       -0.001949
# 2           1.076130          -0.02793        1.277781       -0.001949
# 3          -1.001953          -0.02793        1.458455       -0.001949
# 4           0.244897          -0.02793        1.729466       -0.001949
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_snow_depth  \
# 0               -1.101066            -0.265148         -0.179228
# 1               -1.058108             1.658760         -0.179228
# 2               -1.251420             0.155707         -0.179228
# 3               -0.821838            -0.445514         -0.179228
# 4               -0.746661            -0.164944         -0.179228
#
#    BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  BASEL_temp_max  \
# 0       -0.902918        -0.528623       -0.845652       -0.478356
# ...

# %%
df_scaled3.shape
# Out:
# (22950, 168)

# %%
# Compare the original vs. scaled data
df2.head()
# Out:
#    BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0                  7               2.1            0.85           1.018
# 1                  6               2.1            0.84           1.018
# 2                  8               2.1            0.90           1.018
# 3                  3               2.1            0.92           1.018
# 4                  6               2.1            0.95           1.018
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_snow_depth  \
# 0                    0.32                 0.09                 0
# 1                    0.36                 1.05                 0
# 2                    0.18                 0.30                 0
# 3                    0.58                 0.00                 0
# 4                    0.65                 0.14                 0
#
#    BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  BASEL_temp_max  \
# 0             0.7              6.5             0.8            10.9
# ...

# %% [markdown]
# ## 3. Exporting data

# %%
# Export scaled file

path2="C:/Users/Oksana Stepanova/OneDrive/Документи/ClimateWins/02 Data/Prepared Data/"

df_scaled3.to_csv(os.path.join(path2, 'weather_scaled.csv'))
